# %% [markdown]
# # Homework 5: API Integration and Design
# **Name:**
# **Course:** SEAS 8515
# **Date:**
#
# ---
#
# **Instructions:**
# Delete the option you are NOT completing.
# All written explanations must be included in Markdown cells.
# All code must be runnable and clearly commented.

# %% [markdown]
# ---
# # SELECT ONE OPTION BELOW
#
# Delete the entire section for the option you are NOT completing.
#
# ---

# %% [markdown]
# # OPTION 1: API Ingestion Pipeline (Implementation)
#
# ## 1. API Selection
# Describe the public REST API you selected and why.
#
# ## 2. Pagination Implementation

# %%
# Write your API ingestion code here

# %% [markdown]
# ## 3. Retry Logic Explanation

# %%
# Implement status code checking and retry logic here

# %% [markdown]
# ## 4. Data Storage
# Explain how you saved raw JSON and transformed data.

# %%
# Save raw JSON
# Transform and save CSV

# %% [markdown]
# ## 5. Final Output
# Load your CSV and display total number of records collected.

# %%
# Load CSV and display record count using pandas

# %% [markdown]
# ## 6. Written Response
# 1. Explain pagination logic and stopping condition.
# 2. Explain retry logic and its production relevance.
# 3. Identify HTTP status codes encountered.
# 4. Explain where this fits in an ETL or ELT pipeline.
#
# ---
# DELETE THIS ENTIRE OPTION IF YOU ARE NOT COMPLETING OPTION 1.

# %% [markdown]
# # OPTION 2: Build and Consume a Local API (Implementation)
#
# ## 1. API Design Description
# Briefly describe your API structure and endpoints.

# %%
# Build your Flask or FastAPI application here

# %% [markdown]
# ## 2. Client Interaction
# Demonstrate usage of your API (GET and POST).

# %%
# Client interaction code here

# %% [markdown]
# ## 3. Written Response
# 1. Explain what your API is, how it functions, and why your API is RESTful.
# 2. Discuss how authentication and rate limiting could be added.
# 3. Describe scalability considerations.
#
#
# ---
# DELETE THIS ENTIRE OPTION IF YOU ARE NOT COMPLETING OPTION 2.
